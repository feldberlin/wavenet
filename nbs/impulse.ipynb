# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /Users/purzelrakete/src/github.com/feldberlin/wavenet

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

from wavenet import model, utils, datasets

# %%
p = model.HParams()
n_examples, n_samples = 2**14, 4
X = datasets.stereo_impulse_at_t0(n_examples, n_samples, p, (0.3, 0.7))

# %%
plt.figure(num=None, figsize=(12, 9), dpi=80, facecolor='w', edgecolor='k')
plt.hist(X[:, 0, 0].numpy(), bins=256);
plt.hist(X[:, 1, 0].numpy(), bins=256);
